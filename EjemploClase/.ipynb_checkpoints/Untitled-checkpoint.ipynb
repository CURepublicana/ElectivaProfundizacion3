# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
pwd
# Out:
# 'D:\\CUR-Fuentes\\ElectivaProfundizacion3\\EjemploClase'

# %%
imagen = Image.open('perro.jpg')

# %%
imagen
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1280 at 0x596DAA8>

# %%
type(imagen)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
imagen.size
# Out:
# (1920, 1280)

# %%
array_imagen = np.asarray(imagen)

# %%
array_imagen
# Out:
# array([[[237, 234, 217],
#         [240, 237, 220],
#         [244, 241, 224],
#         ...,
#         [230, 229, 199],
#         [229, 228, 198],
#         [227, 226, 196]],
#
#        [[239, 236, 219],
#         [241, 238, 221],
#         [243, 240, 223],
#         ...,
#         [229, 228, 198],
#         [229, 228, 198],
#         [229, 228, 198]],
#
#        [[240, 237, 220],
#         [241, 238, 221],
#         [242, 239, 222],
#         ...,
#         [228, 227, 197],
#         [229, 228, 197],
#         [230, 229, 198]],
#
#        ...,
#
#        [[ 47,  27,  18],
#         [ 53,  33,  24],
#         [ 55,  35,  26],
#         ...,
#         [ 55,  34,  17],
#         [ 56,  35,  18],
#         [ 57,  36,  19]],
#
#        [[ 55,  36,  29],
#         [ 54,  35,  28],
#         [ 50,  31,  24],
#         ...,
#         [ 58,  35,  19],
#         [ 60,  37,  21],
#         [ 62,  39,  23]],
#
#        [[ 50,  31,  24],
#         [ 52,  33,  26],
#         [ 51,  32,  25],
#         ...,
#         [ 60,  37,  21],
#         [ 67,  41,  26],
#         [ 72,  46,  31]]], dtype=uint8)

# %%
plt.imshow(array_imagen)
