# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
imagen = cv2.imread('perro.jpg')

# %%
plt.imshow(imagen)

# %%
imagen = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imagen) #RGB

# %%
imagen.shape
# Out:
# (1280, 1920, 3)

# %%
imagen2 = cv2.resize(imagen, (600, 500))

# %%
plt.imshow(imagen2)

# %%
ratio_ancho = 0.5
ratio_alto = 0.5

# %%
imagen3 = cv2.resize(imagen, (0,0), imagen, ratio_ancho, ratio_alto)

# %%
plt.imshow(imagen3)

# %%
imagen3.shape
# Out:
# (640, 960, 3)

# %%
imagen4 = cv2.flip(imagen, 1)

# %%
plt.imshow(imagen4)

# %%
imagen4 = cv2.cvtColor(imagen4, cv2.COLOR_RGB2BGR)

# %%
cv2.imwrite('perro_al_reves.jpg', imagen4)
# Out:
# True

# %%
Imagen5 = cv2.flip(imagen, 0)

# %%
plt.imshow(Imagen5)

# %%
cv2.imwrite('perro_al_reves.jpg', Imagen5)
# Out:
# True
