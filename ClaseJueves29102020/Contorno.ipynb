# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
imagen = cv2.imread('cara_perro.jpg')

# %%
plt.imshow(imagen)

# %%
#umbral canny cantiodad de informacion del fondo, cantidad de información del objeto
contorno = cv2.Canny(image= imagen, threshold1=250, threshold2=250)

# %%
plt.imshow(contorno)
