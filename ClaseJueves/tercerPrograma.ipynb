# %%
import cv2 #OpenCV
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
imagen = cv2.imread('Tom.jpg')

# %%
imagen
# Out:
# array([[[ 83,  94, 121],
#         [ 83,  94, 121],
#         [ 82,  93, 120],
#         ...,
#         [ 84,  88, 106],
#         [ 84,  88, 106],
#         [ 83,  87, 105]],
#
#        [[ 83,  94, 121],
#         [ 83,  94, 121],
#         [ 82,  93, 120],
#         ...,
#         [ 84,  88, 106],
#         [ 84,  88, 106],
#         [ 83,  87, 105]],
#
#        [[ 83,  94, 121],
#         [ 83,  94, 121],
#         [ 82,  93, 120],
#         ...,
#         [ 84,  88, 106],
#         [ 84,  88, 106],
#         [ 83,  87, 105]],
#
#        ...,
#
#        [[124, 137, 153],
#         [145, 158, 174],
#         [163, 176, 192],
#         ...,
#         [ 26,  36,  46],
#         [ 26,  37,  45],
#         [ 26,  37,  45]],
#
#        [[127, 140, 156],
#         [136, 149, 165],
#         [159, 172, 188],
#         ...,
#         [ 26,  37,  45],
#         [ 26,  37,  45],
#         [ 26,  37,  45]],
#
#        [[146, 159, 175],
#         [137, 150, 166],
#         [150, 163, 179],
# ...

# %%
type(imagen)
# Out:
# numpy.ndarray

# %%
plt.imshow(imagen)

# %%
#RGB => Red, Green, Blue
#BGR => Blue, Green, Red
imagen_blanco_negro = cv2.imread('Tom.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(imagen_blanco_negro, cmap='gray')

# %%
imagen2 = cv2.resize(imagen, (500, 500))

# %%
plt.imshow(imagen2)

# %% [markdown]
# imagen3 = cv2.flip(imagen, 1)

# %%
imagen3 = cv2.flip(imagen, 1)

# %%
plt.imshow(imagen3)

# %%
imagen4 = cv2.flip(imagen, 0)

# %%
plt.imshow(imagen4)

# %%
imagen5 = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

# %%
    plt.imshow(imagen5)

# %%
cv2.imwrite('tomNormal.jpg', imagen)
# Out:
# True

# %%
cv2.imwrite('tom-al-reves.jpg', imagen4)
# Out:
# True
