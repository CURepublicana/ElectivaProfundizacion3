# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
imagen = Image.open('Tom.jpg')

# %%
type(imagen)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
imagen.size
# Out:
# (720, 1600)

# %%
arreglo = np.asarray(imagen)

# %%
plt.imshow(arreglo)

# %%
arreglo
# Out:
# array([[[121,  94,  83],
#         [121,  94,  83],
#         [120,  93,  82],
#         ...,
#         [106,  88,  84],
#         [106,  88,  84],
#         [105,  87,  83]],
#
#        [[121,  94,  83],
#         [121,  94,  83],
#         [120,  93,  82],
#         ...,
#         [106,  88,  84],
#         [106,  88,  84],
#         [105,  87,  83]],
#
#        [[121,  94,  83],
#         [121,  94,  83],
#         [120,  93,  82],
#         ...,
#         [106,  88,  84],
#         [106,  88,  84],
#         [105,  87,  83]],
#
#        ...,
#
#        [[153, 137, 124],
#         [174, 158, 145],
#         [192, 176, 163],
#         ...,
#         [ 46,  36,  26],
#         [ 45,  37,  26],
#         [ 45,  37,  26]],
#
#        [[156, 140, 127],
#         [165, 149, 136],
#         [188, 172, 159],
#         ...,
#         [ 45,  37,  26],
#         [ 45,  37,  26],
#         [ 45,  37,  26]],
#
#        [[175, 159, 146],
#         [166, 150, 137],
#         [179, 163, 150],
#         ...,
#         [ 46,  38,  27],
#         [ 46,  38,  27],
#         [ 46,  38,  27]]], dtype=uint8)

# %%
(((720*1600)*3)*8)*8
# Out:
# 221184000
